# %% [markdown]
# <a href="https://colab.research.google.com/github/atakanerdogn/MY-PROJECTS-DATA-ANALYSIS/blob/main/CASINO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
casino = pd.read_csv('/content/Casino_Gaming_Data new.csv')
casino.head()
# Out:
#   Fiscal Year            Month Ending                             Licensee  \
# 0     2021/22  06/30/2022 12:00:00 AM         Mohegan Tribe On-Reservation
# 1     2021/22  06/30/2022 12:00:00 AM                  MPTN On-Reservation
# 2     2021/22  06/30/2022 12:00:00 AM  MPI Master Wagering License CT, LLC
# 3     2021/22  06/30/2022 12:00:00 AM                 Mohegan Digital, LLC
# 4     2021/22  05/31/2022 12:00:00 AM         Mohegan Tribe On-Reservation
#
#       Wagers  Patron Winnings  Cancelled Wagers  \
# 0     379023           335505                 5
# 1     671843           685886                 3
# 2  420056291        406814933            164727
# 3  254393582        246515856             11645
# 4     716607           681306                 0
#
#    Online Casino Gaming Win/(Loss)  \
# 0                            43513
# 1                           -14046
# 2                         13076631
# 3                          7866081
# 4                            35301
#
#    Promotional Coupons or Credits Wagered (3)  Promotional Deduction (4)  \
# 0                                        6390                       6390
# 1                                       29041                          0
# 2                                    12372142                    3269158
# 3                                     1397441                    1397441
# 4                                        4130                       4130
#
#    Total Gross Gaming Revenue  Payment (5)
# 0                       37123         6682
# 1                      -14046            0
# 2                     9807473      1765345
# 3                     6468640      1164355
# 4                       31171         5611

# %%
casino.describe()
# Out:
#              Wagers  Patron Winnings  Cancelled Wagers  \
# count  1.430000e+02     1.430000e+02      1.430000e+02
# mean   2.742207e+08     2.655218e+08      1.783408e+05
# std    2.815530e+08     2.725166e+08      2.826004e+05
# min    1.145280e+05     1.113650e+05      0.000000e+00
# 25%    1.407190e+06     1.357855e+06      5.000000e+00
# 50%    2.656540e+08     2.575127e+08      3.887000e+03
# 75%    5.352846e+08     5.156584e+08      2.913700e+05
# max    7.838842e+08     7.573176e+08      1.133136e+06
#
#        Online Casino Gaming Win/(Loss)  \
# count                     1.430000e+02
# mean                      8.520509e+06
# std                       8.921912e+06
# min                      -8.099000e+04
# 25%                       3.713950e+04
# 50%                       7.866081e+06
# 75%                       1.587461e+07
# max                       2.570443e+07
#
#        Promotional Coupons or Credits Wagered (3)  Promotional Deduction (4)  \
# count                                1.430000e+02               1.430000e+02
# mean                                 2.909760e+06               1.470359e+06
# std                                  5.194974e+06               1.512958e+06
# min                                  0.000000e+00               0.000000e+00
# 25%                                  1.118100e+04               6.188500e+03
# 50%                                  1.065100e+06               1.021521e+06
# 75%                                  3.844558e+06               3.071548e+06
# max                                  3.220656e+07               4.163625e+06
#
#        Total Gross Gaming Revenue   Payment (5)
# count                1.430000e+02  1.430000e+02
# mean                 7.050150e+06  1.269229e+06
# std                  7.483596e+06  1.346855e+06
# min                 -8.099000e+04  0.000000e+00
# 25%                  3.172700e+04  5.711000e+03
# 50%                  6.821088e+06  1.227796e+06
# 75%                  1.304302e+07  2.347743e+06
# max                  2.281557e+07  4.106803e+06

# %%
casino.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 11 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Fiscal Year                                 143 non-null    object
#  1   Month Ending                                143 non-null    object
#  2   Licensee                                    143 non-null    object
#  3   Wagers                                      143 non-null    int64
#  4   Patron Winnings                             143 non-null    int64
#  5   Cancelled Wagers                            143 non-null    int64
#  6   Online Casino Gaming Win/(Loss)             143 non-null    int64
#  7   Promotional Coupons or Credits Wagered (3)  143 non-null    int64
#  8   Promotional Deduction (4)                   143 non-null    int64
#  9   Total Gross Gaming Revenue                  143 non-null    int64
#  10  Payment (5)                                 143 non-null    int64
# dtypes: int64(8), object(3)
# memory usage: 12.4+ KB

# %%
casino.shape
# Out:
# (143, 11)

# %%
casino.isnull().sum()
# Out:
# Fiscal Year                                   0
# Month Ending                                  0
# Licensee                                      0
# Wagers                                        0
# Patron Winnings                               0
# Cancelled Wagers                              0
# Online Casino Gaming Win/(Loss)               0
# Promotional Coupons or Credits Wagered (3)    0
# Promotional Deduction (4)                     0
# Total Gross Gaming Revenue                    0
# Payment (5)                                   0
# dtype: int64

# %%
casino.duplicated().sum()
# Out:
# np.int64(0)

# %%
casino.columns
# Out:
# Index(['Fiscal Year', 'Month Ending', 'Licensee', 'Wagers', 'Patron Winnings',
#        'Cancelled Wagers', 'Online Casino Gaming Win/(Loss)',
#        'Promotional Coupons or Credits Wagered (3)',
#        'Promotional Deduction (4)', 'Total Gross Gaming Revenue',
#        'Payment (5)'],
#       dtype='object')

# %%
casino_numeric = casino.select_dtypes(include=np.number)
casino_numeric.head()
# Out:
#       Wagers  Patron Winnings  Cancelled Wagers  \
# 0     379023           335505                 5
# 1     671843           685886                 3
# 2  420056291        406814933            164727
# 3  254393582        246515856             11645
# 4     716607           681306                 0
#
#    Online Casino Gaming Win/(Loss)  \
# 0                            43513
# 1                           -14046
# 2                         13076631
# 3                          7866081
# 4                            35301
#
#    Promotional Coupons or Credits Wagered (3)  Promotional Deduction (4)  \
# 0                                        6390                       6390
# 1                                       29041                          0
# 2                                    12372142                    3269158
# 3                                     1397441                    1397441
# 4                                        4130                       4130
#
#    Total Gross Gaming Revenue  Payment (5)
# 0                       37123         6682
# 1                      -14046            0
# 2                     9807473      1765345
# 3                     6468640      1164355
# 4                       31171         5611

# %%
casino_categorical = casino.select_dtypes(include='object')
casino_categorical.head()
# Out:
#   Fiscal Year            Month Ending                             Licensee
# 0     2021/22  06/30/2022 12:00:00 AM         Mohegan Tribe On-Reservation
# 1     2021/22  06/30/2022 12:00:00 AM                  MPTN On-Reservation
# 2     2021/22  06/30/2022 12:00:00 AM  MPI Master Wagering License CT, LLC
# 3     2021/22  06/30/2022 12:00:00 AM                 Mohegan Digital, LLC
# 4     2021/22  05/31/2022 12:00:00 AM         Mohegan Tribe On-Reservation

# %%
casino_categorical.columns
# Out:
# Index(['Fiscal Year', 'Month Ending', 'Licensee'], dtype='object')

# %%
sns.countplot(y='Licensee',data=casino, palette = 'viridis')
plt.xticks(rotation=90)
plt.show()

# %%
casino_numeric.columns
# Out:
# Index(['Wagers', 'Patron Winnings', 'Cancelled Wagers',
#        'Online Casino Gaming Win/(Loss)',
#        'Promotional Coupons or Credits Wagered (3)',
#        'Promotional Deduction (4)', 'Total Gross Gaming Revenue',
#        'Payment (5)'],
#       dtype='object')

# %%
# wagers through time
wagers = casino.groupby('Fiscal Year')['Wagers'].sum().reset_index()
wagers.head()
# Out:
#   Fiscal Year       Wagers
# 0     2021/22   6374075171
# 1     2022/23  11331775026
# 2     2023/24  14737801245
# 3     2024/25   6769904738

# %%
wagers.plot(kind='bar', x='Fiscal Year', y='Wagers', color='blue')
plt.title('Wagers Through Time')
plt.xlabel('Fiscal Year')
# Out:
# Text(0.5, 0, 'Fiscal Year')

# %%
# patron winnings though years

patron_winnings = casino.groupby('Fiscal Year')['Patron Winnings'].sum().reset_index()
patron_winnings.head()
# Out:
#   Fiscal Year  Patron Winnings
# 0     2021/22       6193645742
# 1     2022/23      10988404212
# 2     2023/24      14251488532
# 3     2024/25       6536082169

# %%
patron_winnings.plot(kind='bar', color='green')
plt.xlabel('Fiscal Year')
plt.ylabel('Patron Winnings')
plt.title('Patron Winnings Through Time')
# Out:
# Text(0.5, 1.0, 'Patron Winnings Through Time')

# %%
# cancelled wagers vs whole wagers

canceled_wagers = casino.groupby('Fiscal Year')['Cancelled Wagers'].sum().reset_index()
canceled_wagers.head()
# Out:
#   Fiscal Year  Cancelled Wagers
# 0     2021/22           1501683
# 1     2022/23           3968716
# 2     2023/24          13199971
# 3     2024/25           6832361

# %%
valid_wagers =

# %%
# total valid wagers
valid_wagers = casino['Wagers'].sum() - casino['Cancelled Wagers'].sum()
valid_wagers
# Out:
# np.int64(39188053449)

# %%
cancelled_wagers = casino['Cancelled Wagers']

df_wagers = pd.merge(wagers, canceled_wagers, on='Fiscal Year')
df_wagers.head()
# Out:
#   Fiscal Year       Wagers  Cancelled Wagers
# 0     2021/22   6374075171           1501683
# 1     2022/23  11331775026           3968716
# 2     2023/24  14737801245          13199971
# 3     2024/25   6769904738           6832361

# %%
# total wagers
sns.barplot(x='Fiscal Year', y='Wagers', data=df_wagers, palette='viridis')
plt.title('Wagers Through Time')
plt.xlabel('Fiscal Year')
plt.ylabel('Wagers')
# Out:
# Text(0, 0.5, 'Wagers')

# %%
# cancelled wagers
sns.barplot(x='Fiscal Year', y='Cancelled Wagers', data=df_wagers, palette='viridis')
# Out:
# <Axes: xlabel='Fiscal Year', ylabel='Cancelled Wagers'>

# %%
casino_numeric.columns
# Out:
# Index(['Wagers', 'Patron Winnings', 'Cancelled Wagers',
#        'Online Casino Gaming Win/(Loss)',
#        'Promotional Coupons or Credits Wagered (3)',
#        'Promotional Deduction (4)', 'Total Gross Gaming Revenue',
#        'Payment (5)'],
#       dtype='object')

# %%
sns.lineplot(x='Fiscal Year', y='Online Casino Gaming Win/(Loss)', data=casino)
# Out:
# <Axes: xlabel='Fiscal Year', ylabel='Online Casino Gaming Win/(Loss)'>

# %%
# patron winnings

sns.lineplot(x='Fiscal Year', y='Patron Winnings', data=casino, color ='green')
# Out:
# <Axes: xlabel='Fiscal Year', ylabel='Patron Winnings'>

# %%
# gross gaming revenue

sns.lineplot(x='Fiscal Year', y='Total Gross Gaming Revenue', data=casino, color='blue')
# Out:
# <Axes: xlabel='Fiscal Year', ylabel='Total Gross Gaming Revenue'>

# %%
sns.lineplot(x='Fiscal Year', y='Wagers', data=casino, color='brown')
# Out:
# <Axes: xlabel='Fiscal Year', ylabel='Wagers'>

# %%
sns.lineplot(x='Fiscal Year', y='Cancelled Wagers', data=casino, color='red')
# Out:
# <Axes: xlabel='Fiscal Year', ylabel='Cancelled Wagers'>

# %%
casino['Valid Wagers'] = casino['Wagers'] - casino['Cancelled Wagers']

# %%
sns.lineplot(x='Fiscal Year', y='Valid Wagers', data=casino, color='green')
# Out:
# <Axes: xlabel='Fiscal Year', ylabel='Valid Wagers'>

# %%
# total gross gaming revenue vs licensee

sns.barplot(x='Licensee', y='Total Gross Gaming Revenue', data=casino, palette='Blues')
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x='Licensee', y='Total Gross Gaming Revenue', data=casino, palette = 'viridis')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Mohegan Tribe On-Reservation'),
#   Text(1, 0, 'MPTN On-Reservation'),
#   Text(2, 0, 'MPI Master Wagering License CT, LLC'),
#   Text(3, 0, 'Mohegan Digital, LLC')])

# %%
casino_numeric.columns
# Out:
# Index(['Wagers', 'Patron Winnings', 'Cancelled Wagers',
#        'Online Casino Gaming Win/(Loss)',
#        'Promotional Coupons or Credits Wagered (3)',
#        'Promotional Deduction (4)', 'Total Gross Gaming Revenue',
#        'Payment (5)'],
#       dtype='object')

# %%
# promotional coupons or credits wagered (3) vs online gaming win

po = casino.groupby('Fiscal Year')['Promotional Coupons or Credits Wagered (3)'].sum().reset_index()
po.head()

po.plot(kind='barh', color='red')
# Out:
# <Axes: >

# %%
#promotional deduction vs online gaming revenue

pd = casino.groupby('Fiscal Year')['Promotional Deduction (4)'].sum().reset_index()
pd.head()

pd.plot(kind='barh', color='red')
# Out:
# <Axes: >

# %%
# promotional deduction vs promotional coupons

po_pd = casino.groupby('Promotional Deduction (4)')['Promotional Coupons or Credits Wagered (3)'].sum().reset_index()
po_pd.head()

corr_matrix_1 = po_pd.corr()
corr_matrix_1.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_61346_row0_col0, #T_61346_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_61346_row0_col1, #T_61346_row1_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_61346" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61346_level0_col0" class="col_heading level0 col0" >Promotional Deduction (4)</th>
#       <th id="T_61346_level0_col1" class="col_heading level0 col1" >Promotional Coupons or Credits Wagered (3)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61346_level0_row0" class="row_heading level0 row0" >Promotional Deduction (4)</th>
#       <td id="T_61346_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_61346_row0_col1" class="data row0 col1" >0.605365</td>
#     </tr>
#     <tr>
#       <th id="T_61346_level0_row1" class="row_heading level0 row1" >Promotional Coupons or Credits Wagered (3)</th>
#       <td id="T_61346_row1_col0" class="data row1 col0" >0.605365</td>
#       <td id="T_61346_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
corr_matrix2 = casino_numeric.corr()
corr_matrix2.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_5943c_row0_col0, #T_5943c_row0_col1, #T_5943c_row1_col0, #T_5943c_row1_col1, #T_5943c_row2_col2, #T_5943c_row3_col3, #T_5943c_row3_col6, #T_5943c_row3_col7, #T_5943c_row4_col4, #T_5943c_row5_col5, #T_5943c_row6_col3, #T_5943c_row6_col6, #T_5943c_row6_col7, #T_5943c_row7_col3, #T_5943c_row7_col6, #T_5943c_row7_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_5943c_row0_col2, #T_5943c_row1_col2 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_5943c_row0_col3 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_5943c_row0_col4, #T_5943c_row1_col4 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_5943c_row0_col5, #T_5943c_row1_col5, #T_5943c_row5_col3 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_5943c_row0_col6, #T_5943c_row0_col7, #T_5943c_row1_col6, #T_5943c_row1_col7 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_5943c_row1_col3, #T_5943c_row3_col0, #T_5943c_row3_col1 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_5943c_row2_col0 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_5943c_row2_col1 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_5943c_row2_col3 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_5943c_row2_col4, #T_5943c_row4_col0, #T_5943c_row4_col1, #T_5943c_row4_col2, #T_5943c_row4_col3, #T_5943c_row4_col5, #T_5943c_row4_col6, #T_5943c_row4_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_5943c_row2_col5 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_5943c_row2_col6, #T_5943c_row2_col7 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_5943c_row3_col2 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_5943c_row3_col4 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_5943c_row3_col5, #T_5943c_row5_col6, #T_5943c_row5_col7 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_5943c_row5_col0, #T_5943c_row5_col1 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_5943c_row5_col2 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_5943c_row5_col4 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_5943c_row6_col0, #T_5943c_row7_col0 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_5943c_row6_col1, #T_5943c_row7_col1 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_5943c_row6_col2, #T_5943c_row7_col2 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_5943c_row6_col4, #T_5943c_row7_col4 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_5943c_row6_col5, #T_5943c_row7_col5 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5943c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5943c_level0_col0" class="col_heading level0 col0" >Wagers</th>
#       <th id="T_5943c_level0_col1" class="col_heading level0 col1" >Patron Winnings</th>
#       <th id="T_5943c_level0_col2" class="col_heading level0 col2" >Cancelled Wagers</th>
#       <th id="T_5943c_level0_col3" class="col_heading level0 col3" >Online Casino Gaming Win/(Loss)</th>
#       <th id="T_5943c_level0_col4" class="col_heading level0 col4" >Promotional Coupons or Credits Wagered (3)</th>
#       <th id="T_5943c_level0_col5" class="col_heading level0 col5" >Promotional Deduction (4)</th>
#       <th id="T_5943c_level0_col6" class="col_heading level0 col6" >Total Gross Gaming Revenue</th>
#       <th id="T_5943c_level0_col7" class="col_heading level0 col7" >Payment (5)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5943c_level0_row0" class="row_heading level0 row0" >Wagers</th>
#       <td id="T_5943c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_5943c_row0_col1" class="data row0 col1" >0.999986</td>
#       <td id="T_5943c_row0_col2" class="data row0 col2" >0.792654</td>
#       <td id="T_5943c_row0_col3" class="data row0 col3" >0.988162</td>
#       <td id="T_5943c_row0_col4" class="data row0 col4" >0.529160</td>
#       <td id="T_5943c_row0_col5" class="data row0 col5" >0.968887</td>
#       <td id="T_5943c_row0_col6" class="data row0 col6" >0.982202</td>
#       <td id="T_5943c_row0_col7" class="data row0 col7" >0.982197</td>
#     </tr>
#     <tr>
#       <th id="T_5943c_level0_row1" class="row_heading level0 row1" >Patron Winnings</th>
#       <td id="T_5943c_row1_col0" class="data row1 col0" >0.999986</td>
#       <td id="T_5943c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_5943c_row1_col2" class="data row1 col2" >0.791001</td>
#       <td id="T_5943c_row1_col3" class="data row1 col3" >0.987337</td>
#       <td id="T_5943c_row1_col4" class="data row1 col4" >0.530883</td>
#       <td id="T_5943c_row1_col5" class="data row1 col5" >0.968870</td>
#       <td id="T_5943c_row1_col6" class="data row1 col6" >0.981223</td>
#       <td id="T_5943c_row1_col7" class="data row1 col7" >0.981217</td>
#     </tr>
#     <tr>
#       <th id="T_5943c_level0_row2" class="row_heading level0 row2" >Cancelled Wagers</th>
#       <td id="T_5943c_row2_col0" class="data row2 col0" >0.792654</td>
#       <td id="T_5943c_row2_col1" class="data row2 col1" >0.791001</td>
#       <td id="T_5943c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_5943c_row2_col3" class="data row2 col3" >0.821653</td>
#       <td id="T_5943c_row2_col4" class="data row2 col4" >0.286045</td>
#       <td id="T_5943c_row2_col5" class="data row2 col5" >0.726616</td>
#       <td id="T_5943c_row2_col6" class="data row2 col6" >0.832672</td>
#       <td id="T_5943c_row2_col7" class="data row2 col7" >0.832695</td>
#     </tr>
#     <tr>
#       <th id="T_5943c_level0_row3" class="row_heading level0 row3" >Online Casino Gaming Win/(Loss)</th>
#       <td id="T_5943c_row3_col0" class="data row3 col0" >0.988162</td>
#       <td id="T_5943c_row3_col1" class="data row3 col1" >0.987337</td>
#       <td id="T_5943c_row3_col2" class="data row3 col2" >0.821653</td>
#       <td id="T_5943c_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_5943c_row3_col4" class="data row3 col4" >0.474272</td>
#       <td id="T_5943c_row3_col5" class="data row3 col5" >0.958824</td>
#       <td id="T_5943c_row3_col6" class="data row3 col6" >0.998350</td>
#       <td id="T_5943c_row3_col7" class="data row3 col7" >0.998348</td>
#     </tr>
#     <tr>
#       <th id="T_5943c_level0_row4" class="row_heading level0 row4" >Promotional Coupons or Credits Wagered (3)</th>
#       <td id="T_5943c_row4_col0" class="data row4 col0" >0.529160</td>
#       <td id="T_5943c_row4_col1" class="data row4 col1" >0.530883</td>
#       <td id="T_5943c_row4_col2" class="data row4 col2" >0.286045</td>
#       <td id="T_5943c_row4_col3" class="data row4 col3" >0.474272</td>
#       <td id="T_5943c_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_5943c_row4_col5" class="data row4 col5" >0.616282</td>
#       <td id="T_5943c_row4_col6" class="data row4 col6" >0.440832</td>
#       <td id="T_5943c_row4_col7" class="data row4 col7" >0.440810</td>
#     </tr>
#     <tr>
#       <th id="T_5943c_level0_row5" class="row_heading level0 row5" >Promotional Deduction (4)</th>
#       <td id="T_5943c_row5_col0" class="data row5 col0" >0.968887</td>
#       <td id="T_5943c_row5_col1" class="data row5 col1" >0.968870</td>
#       <td id="T_5943c_row5_col2" class="data row5 col2" >0.726616</td>
#       <td id="T_5943c_row5_col3" class="data row5 col3" >0.958824</td>
#       <td id="T_5943c_row5_col4" class="data row5 col4" >0.616282</td>
#       <td id="T_5943c_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_5943c_row5_col6" class="data row5 col6" >0.940936</td>
#       <td id="T_5943c_row5_col7" class="data row5 col7" >0.940924</td>
#     </tr>
#     <tr>
#       <th id="T_5943c_level0_row6" class="row_heading level0 row6" >Total Gross Gaming Revenue</th>
#       <td id="T_5943c_row6_col0" class="data row6 col0" >0.982202</td>
#       <td id="T_5943c_row6_col1" class="data row6 col1" >0.981223</td>
#       <td id="T_5943c_row6_col2" class="data row6 col2" >0.832672</td>
#       <td id="T_5943c_row6_col3" class="data row6 col3" >0.998350</td>
#       <td id="T_5943c_row6_col4" class="data row6 col4" >0.440832</td>
#       <td id="T_5943c_row

# %%
sns.heatmap(corr_matrix2, annot=True, cmap='Blues')
# Out:
# <Axes: >

# %%
# boxplots

sns.boxplot(x='Licensee', y='Total Gross Gaming Revenue', data=casino, palette = 'Blues')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Mohegan Tribe On-Reservation'),
#   Text(1, 0, 'MPTN On-Reservation'),
#   Text(2, 0, 'MPI Master Wagering License CT, LLC'),
#   Text(3, 0, 'Mohegan Digital, LLC')])

# %%
# boxplot 2

sns.boxplot(x='Licensee', y='Online Casino Gaming Win/(Loss)', data=casino, palette = 'Set2')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Mohegan Tribe On-Reservation'),
#   Text(1, 0, 'MPTN On-Reservation'),
#   Text(2, 0, 'MPI Master Wagering License CT, LLC'),
#   Text(3, 0, 'Mohegan Digital, LLC')])

# %%
# boxplot 3

sns.boxplot(x='Licensee', y='Patron Winnings', data=casino, palette = 'viridis')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Mohegan Tribe On-Reservation'),
#   Text(1, 0, 'MPTN On-Reservation'),
#   Text(2, 0, 'MPI Master Wagering License CT, LLC'),
#   Text(3, 0, 'Mohegan Digital, LLC')])

# %%
sns.countplot(y='Licensee',data=casino, palette = 'viridis')
plt.xticks(rotation=90)
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

x = casino_numeric.drop('Total Gross Gaming Revenue', axis = 1)
y = casino_numeric['Total Gross Gaming Revenue']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

L = LinearRegression()
L.fit(x_train, y_train)

y_pred = L.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R-squared:", r2)

df = pd.DataFrame({'y_test': y_test, 'y_pred': y_pred})
df.head()
# Out:
# Mean Squared Error: 0.2914232783876441
# R-squared: 0.9999999999999942
#        y_test        y_pred
# 117  13790282  1.379028e+07
# 19    7697631  7.697630e+06
# 82   17692202  1.769220e+07
# 97   20257409  2.025741e+07
# 56      36434  3.643381e+04

# %%
sns.lineplot(x='y_test', y='y_pred', data=df)
# Out:
# <Axes: xlabel='y_test', ylabel='y_pred'>

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(x_train, y_train)

y_pred_rf = rf.predict(x_test)

mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

print("Mean Squared Error (Random Forest):", mse_rf)
print("R-squared (Random Forest):", r2_rf)

df_rf = pd.DataFrame({'y_test': y_test, 'y_pred_rf': y_pred_rf})
df_rf.head()

sns.lineplot(x='y_test', y='y_pred_rf', data=df_rf)
plt.show()
# Out:
# Mean Squared Error (Random Forest): 114154224279.84193
# R-squared (Random Forest): 0.99773900519452

# %%
from sklearn.ensemble import GradientBoostingRegressor

gb = GradientBoostingRegressor(n_estimators=100, random_state=42)
gb.fit(x_train, y_train)

y_pred_gb = gb.predict(x_test)

mse_gb = mean_squared_error(y_test, y_pred_gb)
r2_gb = r2_score(y_test, y_pred_gb)

print("Mean Squared Error (Gradient Boosting):", mse_gb)
print("R-squared (Gradient Boosting):", r2_gb)

df_gb = pd.DataFrame({'y_test': y_test, 'y_pred_gb': y_pred_gb})
df_gb.head()

sns.lineplot(x='y_test', y='y_pred_gb', data=df_gb)
plt.show()
# Out:
# Mean Squared Error (Gradient Boosting): 76046794074.05322
# R-squared (Gradient Boosting): 0.9984937797312402
